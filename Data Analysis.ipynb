# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (16,9)

# %%
pwd
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
path = '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
# for i in range(3):
#     df = (pd.read_csv('save/rewards{}.csv'.format(i))).drop(columns='Unnamed: 0')
#     df.plot(figsize=(16,9))

# %%
read_path = path+'/model_output/traffic/DPG_5v5_v3/statistics.csv'
read_path
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL/model_output/traffic/DPG_5v5_v3/statistics.csv'

# %%
stats = pd.read_csv(read_path).set_index('episode')
print(stats.shape)
stats.head()
# Out:
# (13178, 30)
#          collision_0  collision_1  collision_2  collision_3  collision_4  \
# episode
# 1                  6            2            1            4            2
# 2                  4            1            2            4            2
# 3                  4            4            1            2            1
# 4                  4            1            1            6            3
# 5                  1            2            1            1            2
#
#          collision_5  collision_6  collision_7  collision_8  collision_9  \
# episode
# 1                  3            1            1            1            3
# 2                  3            0            2            2            1
# 3                  2            2            1            3            1
# 4                  1            2            1            2            1
# 5                  1            2            4            1            1
#
#            ...       loss_0    loss_1    loss_2    loss_3    loss_4    loss_5  \
# episode    ...
# 1          ...    -0.009401  0.023923 -0.020179  0.263775 -0.011449 -0.086223
# 2          ...    -0.025161 -0.072810 -0.006746 -0.172119  0.206092 -0.016004
# 3          ...     0.053110  0.077087  0.013490  0.057645 -0.078958  0.046344
# 4          ...     0.007445  0.034219 -0.133727 -0.134885  0.074792  0.031680
# 5          ...     0.042549  0.042879  0.001923  0.063464  0.173924 -0.163919
#
#            loss_6    loss_7    loss_8    loss_9
# episode
# 1       -0.009204 -0.078111  0.284139 -0.019453
# 2        0.000000  0.071175  0.035653 -0.007156
# 3        0.104392  0.169723  0.044198  0.039501
# 4       -0.010791  0.000893  0.053548  0.133439
# 5       -0.012271  0.065270 -0.026677  0.188080
#
# [5 rows x 30 columns]

# %%
#collision for agent0
stats.iloc[::10,:10].sum(axis=1).plot(alpha=0.5);
plt.ylabel('collision');
plt.title('Total collision in an episode');

# %%
#reward 
stats.iloc[::10,10:20].sum(axis=1).plot(alpha=0.5);
plt.ylabel('reward');
plt.title('Total reward in an episode');

# %%
for i in range(10,20):
    stats.iloc[::10,i].plot(alpha=0.5);
    plt.legend();
    plt.ylabel('reward');
    plt.title('Reward in an episode');
    plt.show();

# %%
#loss for agent0
stats.iloc[::10,20:30].mean(axis=1).plot(alpha=0.5);
plt.ylabel('loss');
plt.title('Mean loss (DPG) in an episode');
